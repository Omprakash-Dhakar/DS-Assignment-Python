# %%
import numpy as np
import pandas as pd
import os
import torch

# %%
os.chdir('C:\\Users\\DELL\\Desktop\\DS-Assignment')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Desktop\\DS-Assignment'

# %% [markdown]
# # Loading the Amazon & Flipcart Datasets

# %%
Amazon_dataset = pd.read_csv("amz_com-ecommerce_sample.csv", encoding='utf-8', encoding_errors='ignore')
Amazon_dataset.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
Amazon_dataset.shape
# Out:
# (20000, 15)

# %%
Flipcart_dataset = pd.read_csv('flipkart_com-ecommerce_sample.csv', encoding='utf-8', encoding_errors='ignore')
Flipcart_dataset.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
Flipcart_dataset.shape
# Out:
# (20000, 15)

# %%
Amazon = Amazon_dataset[['product_name','retail_price','discounted_price']]
Amazon.head()
# Out:
#                             product_name  retail_price  discounted_price
# 0    Alisha Solid Women's Cycling Shorts           982               438
# 1    FabHomeDecor Fabric Double Sofa Bed         32143             29121
# 2                             AW Bellies           991               551
# 3    Alisha Solid Women's Cycling Shorts           694               325
# 4  Sicons All Purpose Arnica Dog Shampoo           208               258

# %%
Flipcart = Flipcart_dataset[['product_name','retail_price','discounted_price']]
Flipcart.head()
# Out:
#                             product_name  retail_price  discounted_price
# 0    Alisha Solid Women's Cycling Shorts         999.0             379.0
# 1    FabHomeDecor Fabric Double Sofa Bed       32157.0           22646.0
# 2                             AW Bellies         999.0             499.0
# 3    Alisha Solid Women's Cycling Shorts         699.0             267.0
# 4  Sicons All Purpose Arnica Dog Shampoo         220.0             210.0

# %%
# !pip install sentence_transformers
# Out:
# ...
#      ---------------------------------------- 86.0/86.0 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 5.5/5.5 MB 3.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 167.2/167.2 MB 3.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.1/1.1 MB 5.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.1/1.1 MB 4.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 182.4/182.4 kB 5.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.3/3.3 MB 4.2 MB/s eta 0:00:00
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125925 sha256=365d739466adc3e3a4d9f427755c07c7815319f82667d1b9310d845f53de99e1
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\4b\68\65\aba8be86302d9988b832f5e1f3417a87e4a868d396e4329f0a
# ...

# %%
from sentence_transformers import SentenceTransformer as st, util

# %%
# Instantiate a model of the SentenceTransformer class
model = st('all-MiniLM-L6-v2')
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )

# %%
# Compute embedding for both Amazon and Flipkart product names
Amazon_embedding = model.encode(Amazon.product_name,convert_to_tensor=True)
Flipcart_embedding = model.encode(Flipcart.product_name,convert_to_tensor=True)

# %%
Amazon_embedding.shape
# Out:
# torch.Size([20000, 384])

# %%
Flipcart_embedding.shape
# Out:
# torch.Size([20000, 384])

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim_scores = util.cos_sim(Amazon_embedding, Flipcart_embedding)
print(cosine_sim_scores)
# Out:
# tensor([[1.0000, 0.1898, 0.2337,  ..., 0.1396, 0.1396, 0.1396],
#         [0.1898, 1.0000, 0.0277,  ..., 0.1051, 0.1051, 0.1051],
#         [0.2337, 0.0277, 1.0000,  ..., 0.0687, 0.0687, 0.0687],
#         ...,
#         [0.1396, 0.1051, 0.0687,  ..., 1.0000, 1.0000, 1.0000],
#         [0.1396, 0.1051, 0.0687,  ..., 1.0000, 1.0000, 1.0000],
#         [0.1396, 0.1051, 0.0687,  ..., 1.0000, 1.0000, 1.0000]])

# %%
# Storing the index of a similar Flipkart product corresponding to each Amazon product 
similar_prod_indexes = []

for i in range(20000):
    max_score_idxs = torch.topk(cosine_sim_scores[i],k=5,largest=True,sorted=True).indices
    for idx in max_score_idxs:
        if idx != i:
            similar_prod_indexes.append(idx)
            break

# %%
Amazon_dataset.product_name[2936], Flipcart_dataset.product_name[similar_prod_indexes[2936]]
# Out:
# ("Folklore Festive Sleeveless Solid Women's Top",
#  "Folklore Festive Sleeveless Printed Women's Top")

# %%
# Extracting the details such as retail price and discounted price for both Flipkart and Amazon similar products
flipkart_prod_data = []
amazon_prod_data = []

for idx, prod_name in enumerate(Amazon.product_name):
    flipkart_prod_data.append(Flipcart.iloc[similar_prod_indexes[idx]])
    amazon_prod_data.append(Amazon.iloc[idx])

# %%
flipkart_prod_data = pd.DataFrame(flipkart_prod_data)
flipkart_prod_data.columns = ['Product name in Flipkart','Retail Price in Flipkart','Discounted Price in Flipkart']
amazon_prod_data = pd.DataFrame(amazon_prod_data)
amazon_prod_data.columns = ['Product name in Amazon','Retail Price in Amazon','Discounted Price in Amazon']

# %%
flipkart_prod_data.head()
# Out:
#                          Product name in Flipkart  Retail Price in Flipkart  \
# 3             Alisha Solid Women's Cycling Shorts                     699.0
# 16            FabHomeDecor Fabric Double Sofa Bed                   32157.0
# 17691                            i-Sports Bellies                     899.0
# 0             Alisha Solid Women's Cycling Shorts                     999.0
# 20     Sicons Conditioning Conditoner Dog Shampoo                     110.0
#
#        Discounted Price in Flipkart
# 3                             267.0
# 16                          22646.0
# 17691                         399.0
# 0                             379.0
# 20                            100.0

# %%
amazon_prod_data.head()
# Out:
#                   Product name in Amazon  Retail Price in Amazon  \
# 0    Alisha Solid Women's Cycling Shorts                     982
# 1    FabHomeDecor Fabric Double Sofa Bed                   32143
# 2                             AW Bellies                     991
# 3    Alisha Solid Women's Cycling Shorts                     694
# 4  Sicons All Purpose Arnica Dog Shampoo                     208
#
#    Discounted Price in Amazon
# 0                         438
# 1                       29121
# 2                         551
# 3                         325
# 4                         258

# %%
flipkart_prod_final_data = flipkart_prod_data.reset_index(drop=True)
flipkart_prod_final_data.head()
# Out:
#                      Product name in Flipkart  Retail Price in Flipkart  \
# 0         Alisha Solid Women's Cycling Shorts                     699.0
# 1         FabHomeDecor Fabric Double Sofa Bed                   32157.0
# 2                            i-Sports Bellies                     899.0
# 3         Alisha Solid Women's Cycling Shorts                     999.0
# 4  Sicons Conditioning Conditoner Dog Shampoo                     110.0
#
#    Discounted Price in Flipkart
# 0                         267.0
# 1                       22646.0
# 2                         399.0
# 3                         379.0
# 4                         100.0

# %%
amazon_prod_data.shape, flipkart_prod_final_data.shape
# Out:
# ((20000, 3), (20000, 3))

# %%
final_prod_data = pd.concat([flipkart_prod_final_data,amazon_prod_data],axis=1)
final_prod_data.to_csv('final_result.csv')

# %%
final_prod_data.head()
# Out:
#                      Product name in Flipkart  Retail Price in Flipkart  \
# 0         Alisha Solid Women's Cycling Shorts                     699.0
# 1         FabHomeDecor Fabric Double Sofa Bed                   32157.0
# 2                            i-Sports Bellies                     899.0
# 3         Alisha Solid Women's Cycling Shorts                     999.0
# 4  Sicons Conditioning Conditoner Dog Shampoo                     110.0
#
#    Discounted Price in Flipkart                 Product name in Amazon  \
# 0                         267.0    Alisha Solid Women's Cycling Shorts
# 1                       22646.0    FabHomeDecor Fabric Double Sofa Bed
# 2                         399.0                             AW Bellies
# 3                         379.0    Alisha Solid Women's Cycling Shorts
# 4                         100.0  Sicons All Purpose Arnica Dog Shampoo
#
#    Retail Price in Amazon  Discounted Price in Amazon
# ...
